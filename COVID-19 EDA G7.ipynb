# %% [markdown]
# # Proyecto guiado COVID-19
#
# Por Skills.For.Industry
# www.skillsforindustry.org

# %% [markdown]
# Durante este proyecto guiado analizaremos los datos del Coroavirus al rededor del mundo.

# %%
# paso 1 . importación de librerías 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Bruno Ortega\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# En este notebook haremos un proyecto de covid

# %%
# cargar los datos

data = pd.read_csv('covid_19_data.csv' , encoding='utf-8')

# %% [markdown]
# el utf-8 sirve para reconocer los archivos excel y se pueda leer.

# %%
# observar los datos

data.head(20)
# Out:
#     SNo ObservationDate  Province/State  Country/Region      Last Update  \
# 0     1      01/22/2020           Anhui  Mainland China  1/22/2020 17:00
# 1     2      01/22/2020         Beijing  Mainland China  1/22/2020 17:00
# 2     3      01/22/2020       Chongqing  Mainland China  1/22/2020 17:00
# 3     4      01/22/2020          Fujian  Mainland China  1/22/2020 17:00
# 4     5      01/22/2020           Gansu  Mainland China  1/22/2020 17:00
# 5     6      01/22/2020       Guangdong  Mainland China  1/22/2020 17:00
# 6     7      01/22/2020         Guangxi  Mainland China  1/22/2020 17:00
# 7     8      01/22/2020         Guizhou  Mainland China  1/22/2020 17:00
# 8     9      01/22/2020          Hainan  Mainland China  1/22/2020 17:00
# 9    10      01/22/2020           Hebei  Mainland China  1/22/2020 17:00
# 10   11      01/22/2020    Heilongjiang  Mainland China  1/22/2020 17:00
# 11   12      01/22/2020           Henan  Mainland China  1/22/2020 17:00
# ...

# %%
data.tail(20)
# Out:
#            SNo ObservationDate                  Province/State  \
# 306409  306410      05/29/2021               Western Australia
# 306410  306411      05/29/2021                       Wisconsin
# 306411  306412      05/29/2021                         Wyoming
# 306412  306413      05/29/2021                        Xinjiang
# 306413  306414      05/29/2021                        Yamagata
# 306414  306415      05/29/2021                       Yamaguchi
# 306415  306416      05/29/2021  Yamalo-Nenets Autonomous Okrug
# 306416  306417      05/29/2021                       Yamanashi
# 306417  306418      05/29/2021                Yaroslavl Oblast
# 306418  306419      05/29/2021                         Yucatan
# 306419  306420      05/29/2021                           Yukon
# 306420  306421      05/29/2021                          Yunnan
# 306421  306422      05/29/2021                Zabaykalsky Krai
# 306422  306423      05/29/2021                       Zacatecas
# ...

# %% [markdown]
# Limpieza de datos

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB

# %% [markdown]
# ###### podemos detectar que 'ObservationDate' y 'Last Update' están en formato Object, necesitamos cambar esto a un DateTime

# %%
#Hazlo aquí
data["ObservationDate"] = pd.to_datetime(data["ObservationDate"])
data["Last Update"] = pd.to_datetime(data["Last Update"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  datetime64[ns]
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  datetime64[ns]
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 18.7+ MB

# %%
data["Last Update"]
# Out:
# 0        2020-01-22 17:00:00
# 1        2020-01-22 17:00:00
# 2        2020-01-22 17:00:00
# 3        2020-01-22 17:00:00
# 4        2020-01-22 17:00:00
#                  ...
# 306424   2021-05-30 04:20:55
# 306425   2021-05-30 04:20:55
# 306426   2021-05-30 04:20:55
# 306427   2021-05-30 04:20:55
# 306428   2021-05-30 04:20:55
# Name: Last Update, Length: 306429, dtype: datetime64[ns]

# %% [markdown]
# Revisa datos nulos. ¿Qué tantos hay?

# %%
#Hazlo aquí
data.isnull().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78100
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %%
#examinamos la información de nuestra base de datos y los tipos de dato
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  datetime64[ns]
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  datetime64[ns]
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 18.7+ MB

# %%
# otra forma de ver el tipo de dato
data.dtypes
# Out:
# SNo                         int64
# ObservationDate    datetime64[ns]
# Province/State             object
# Country/Region             object
# Last Update        datetime64[ns]
# Confirmed                 float64
# Deaths                    float64
# Recovered                 float64
# dtype: object

# %% [markdown]
# * podemos ver que hemos cambiado el formato objeto a un formato de tiempo

# %% [markdown]
# Revisa el tamaño del dataset

# %%
#obtener el tamaño del dataset
data.shape
# Out:
# (306429, 8)

# %% [markdown]
# Revisa el día de la última observación

# %%
data["ObservationDate"].tail(1)
# Out:
# 306428   2021-05-29
# Name: ObservationDate, dtype: datetime64[ns]

# %%
data1 = data.sort_values(by=['Last Update'],ascending=False)
data1
# Out:
#            SNo ObservationDate        Province/State  Country/Region  \
# 306428  306429      2021-05-29          Zuid-Holland     Netherlands
# 305915  305916      2021-05-29              Campania           Italy
# 305924  305925      2021-05-29             Catalonia           Spain
# 305923  305924      2021-05-29       Castilla y Leon           Spain
# 305922  305923      2021-05-29  Castilla - La Mancha           Spain
# ...        ...             ...                   ...             ...
# 26          27      2020-01-22                Shanxi  Mainland China
# 25          26      2020-01-22              Shanghai  Mainland China
# 24          25      2020-01-22              Shandong  Mainland China
# 23          24      2020-01-22               Shaanxi  Mainland China
# 0            1      2020-01-22                 Anhui  Mainland China
#
#                Last Update  Confirmed   Deaths  Recovered
# 306428 2021-05-30 04:20:55   391559.0   4252.0        0.0
# ...

# %%
last_update = data1.head(1)
last_update
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 306428  306429      2021-05-29   Zuid-Holland    Netherlands
#
#                Last Update  Confirmed  Deaths  Recovered
# 306428 2021-05-30 04:20:55   391559.0  4252.0        0.0

# %% [markdown]
# continuamos explorando nuestra base de datos. Imprime los datos únicos para la columna de Province/State

# %%
#Hazlo aquí
data["Province/State"].unique()
# Out:
# array(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hong Kong', 'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu',
#        'Jiangxi', 'Jilin', 'Liaoning', 'Macau', 'Ningxia', 'Qinghai',
#        'Shaanxi', 'Shandong', 'Shanghai', 'Shanxi', 'Sichuan', 'Taiwan',
#        'Tianjin', 'Tibet', 'Washington', 'Xinjiang', 'Yunnan', 'Zhejiang',
#        nan, 'Unknown', 'Chicago', 'Illinois', 'California', 'Arizona',
#        'Ontario', 'New South Wales', 'Victoria', 'British Columbia',
#        'Bavaria', 'Queensland', 'Chicago, IL', 'South Australia',
#        'Boston, MA', 'Los Angeles, CA', 'Orange, CA', 'Santa Clara, CA',
#        'Seattle, WA', 'Tempe, AZ', 'San Benito, CA', 'Toronto, ON',
#        'London, ON', 'Madison, WI', 'Cruise Ship',
#        'Diamond Princess cruise ship', 'San Diego County, CA',
#        'San Antonio, TX', 'Ashland, NE', 'Travis, CA',
# ...

# %% [markdown]
# Imprime el **número** de valores únicos ahora

# %%
len(data['Province/State'].unique())
# Out:
# 738

# %%
data["Province/State"].nunique()
# Out:
# 737

# %% [markdown]
# Revisa, de reojo, ¿hay algún país que tenga mal escrito el nombre?

# %%
#explorar los valores únicos de country/Region
data['Country/Region'].unique()
# Out:
# array(['Mainland China', 'Hong Kong', 'Macau', 'Taiwan', 'US', 'Japan',
#        'Thailand', 'South Korea', 'China', 'Kiribati', 'Singapore',
#        'Philippines', 'Malaysia', 'Vietnam', 'Australia', 'Mexico',
#        'Brazil', 'Colombia', 'France', 'Nepal', 'Canada', 'Cambodia',
#        'Sri Lanka', 'Ivory Coast', 'Germany', 'Finland',
#        'United Arab Emirates', 'India', 'Italy', 'UK', 'Russia', 'Sweden',
#        'Spain', 'Belgium', 'Others', 'Egypt', 'Iran', 'Israel', 'Lebanon',
#        'Iraq', 'Oman', 'Afghanistan', 'Bahrain', 'Kuwait', 'Austria',
#        'Algeria', 'Croatia', 'Switzerland', 'Pakistan', 'Georgia',
#        'Greece', 'North Macedonia', 'Norway', 'Romania', 'Denmark',
#        'Estonia', 'Netherlands', 'San Marino', ' Azerbaijan', 'Belarus',
#        'Iceland', 'Lithuania', 'New Zealand', 'Nigeria', 'North Ireland',
#        'Ireland', 'Luxembourg', 'Monaco', 'Qatar', 'Ecuador',
#        'Azerbaijan', 'Czech Republic', 'Armenia', 'Dominican Republic',
# ...

# %%
paisregion = data.groupby(["Country/Region", "Province/State"]).max()
paisregion.loc["Mexico"].head(33)
#sacamos la ultima fecha por región aquí (son los registros ultimos)
# Out:
#                         SNo ObservationDate         Last Update  Confirmed  \
# Province/State
# Aguascalientes       305840      2021-05-29 2021-05-30 04:20:55    26501.0
# Baja California      305886      2021-05-29 2021-05-30 04:20:55    49091.0
# Baja California Sur  305887      2021-05-29 2021-05-30 04:20:55    32041.0
# Campeche             305917      2021-05-29 2021-05-30 04:20:55    10174.0
# Chiapas              305939      2021-05-29 2021-05-30 04:20:55    11413.0
# Chihuahua            305941      2021-05-29 2021-05-30 04:20:55    55547.0
# Ciudad de Mexico     305946      2021-05-29 2021-05-30 04:20:55   657832.0
# Coahuila             305947      2021-05-29 2021-05-30 04:20:55    68802.0
# Colima               305948      2021-05-29 2021-05-30 04:20:55    11894.0
# Durango              305969      2021-05-29 2021-05-30 04:20:55    34205.0
# Guanajuato           306007      2021-05-29 2021-05-30 04:20:55   131934.0
# ...

# %% [markdown]
# Crea un dataframe que contenga únicamente los datos de China llamado "China" y uno para México

# %%
df_mexico = data[data["Country/Region"]== 'Mexico']
df_mexico
# Out:
# (Empty DataFrame
#  Columns: [SNo, ObservationDate, Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
#  Index: [],
#             SNo ObservationDate Province/State Country/Region  \
#  83          84      2020-01-23            NaN         Mexico
#  2753      2754      2020-02-28            NaN         Mexico
#  2842      2843      2020-02-29            NaN         Mexico
#  2965      2966      2020-03-01            NaN         Mexico
#  3097      3098      2020-03-02            NaN         Mexico
#  ...        ...             ...            ...            ...
#  306341  306342      2021-05-29       Tlaxcala         Mexico
#  306369  306370      2021-05-29        Unknown         Mexico
#  306389  306390      2021-05-29       Veracruz         Mexico
#  306418  306419      2021-05-29        Yucatan         Mexico
#  306422  306423      2021-05-29      Zacatecas         Mexico
#
#                 Last Update  Confirmed  Deaths  Recovered
# ...

# %%
df_china = data[(data["Country/Region"]== "Mainland China") + (data["Country/Region"]== "China") + (data["Country/Region"]== "Taiwan")]
df_china["Country/Region"].unique()
# Out:
# array(['Mainland China', 'Taiwan', 'China'], dtype=object)

# %%
df_mexico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12282 entries, 83 to 306422
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              12282 non-null  int64
#  1   ObservationDate  12282 non-null  datetime64[ns]
#  2   Province/State   12199 non-null  object
#  3   Country/Region   12282 non-null  object
#  4   Last Update      12282 non-null  datetime64[ns]
#  5   Confirmed        12282 non-null  float64
#  6   Deaths           12282 non-null  float64
#  7   Recovered        12282 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 863.6+ KB

# %%
df_mexico = df_mexico.reset_index()
df_mexico["Province/State"] = df_mexico["Province/State"].str.replace("Unknown", "Mexico")
df_mexico
# Out:
#       index     SNo ObservationDate Province/State Country/Region  \
# 0     27399   27400      2020-05-20         Mexico         Mexico
# 1     27855   27856      2020-05-21         Mexico         Mexico
# 2     28311   28312      2020-05-22         Mexico         Mexico
# 3     28767   28768      2020-05-23         Mexico         Mexico
# 4     29223   29224      2020-05-24         Mexico         Mexico
# ..      ...     ...             ...            ...            ...
# 370  303086  303087      2021-05-25         Mexico         Mexico
# 371  303851  303852      2021-05-26         Mexico         Mexico
# 372  304616  304617      2021-05-27         Mexico         Mexico
# 373  305381  305382      2021-05-28         Mexico         Mexico
# 374  306146  306147      2021-05-29         Mexico         Mexico
#
#             Last Update  Confirmed   Deaths  Recovered
# 0   2021-04-02 15:13:53     9346.0    563.0     7365.0
# 1   2021-04-02 15:13:53     9661.0    622.0     7663.0
# ...

# %%
df_china.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              0 non-null      int64
#  1   ObservationDate  0 non-null      datetime64[ns]
#  2   Province/State   0 non-null      object
#  3   Country/Region   0 non-null      object
#  4   Last Update      0 non-null      datetime64[ns]
#  5   Confirmed        0 non-null      float64
#  6   Deaths           0 non-null      float64
#  7   Recovered        0 non-null      float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
df_mexico
# Out:
#       index     SNo ObservationDate Province/State Country/Region  \
# 0     27399   27400      2020-05-20         Mexico         Mexico
# 1     27855   27856      2020-05-21         Mexico         Mexico
# 2     28311   28312      2020-05-22         Mexico         Mexico
# 3     28767   28768      2020-05-23         Mexico         Mexico
# 4     29223   29224      2020-05-24         Mexico         Mexico
# ..      ...     ...             ...            ...            ...
# 370  303086  303087      2021-05-25         Mexico         Mexico
# 371  303851  303852      2021-05-26         Mexico         Mexico
# 372  304616  304617      2021-05-27         Mexico         Mexico
# 373  305381  305382      2021-05-28         Mexico         Mexico
# 374  306146  306147      2021-05-29         Mexico         Mexico
#
#             Last Update  Confirmed   Deaths  Recovered
# 0   2021-04-02 15:13:53     9346.0    563.0     7365.0
# 1   2021-04-02 15:13:53     9661.0    622.0     7663.0
# ...

# %% [markdown]
# ## Limpieza de Datos nulos y NaN

# %% [markdown]
# Revisa el número de datos nulos para México e imprime el porcentaje de datos nulos por columna

# %%
#Hazlo aquí
df_mexico.isnull().sum()
# Out:
# SNo                 0
# ObservationDate     0
# Province/State     83
# Country/Region      0
# Last Update         0
# Confirmed           0
# Deaths              0
# Recovered           0
# dtype: int64

# %%
((df_mexico.isnull().sum())/len(df_mexico))*100
#esto es de Nadia, sirve para sacar el promedio, pero ella si tiene datos nulos.
# Out:
# SNo                0.000000
# ObservationDate    0.000000
# Province/State     0.675786
# Country/Region     0.000000
# Last Update        0.000000
# Confirmed          0.000000
# Deaths             0.000000
# Recovered          0.000000
# dtype: float64

# %% [markdown]
# Después, llena los datos nulos de la columna de estado con los datos del país. Por ejemplo, si no tiene el estado, en lugar de decir "Morelia" llenalo con "México". ¿Es esta una buena opción? ¿Qué podrías hacer diferente?
#
# Hint: utiliza data[""].fillna(data[""], inplace)

# %%
#Hazlo aquí
df_mexico["Province/State"]= df_mexico["Province/State"].fillna("México")
df_mexico.info()
#df_mexico.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12282 entries, 83 to 306422
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              12282 non-null  int64
#  1   ObservationDate  12282 non-null  datetime64[ns]
#  2   Province/State   12282 non-null  object
#  3   Country/Region   12282 non-null  object
#  4   Last Update      12282 non-null  datetime64[ns]
#  5   Confirmed        12282 non-null  float64
#  6   Deaths           12282 non-null  float64
#  7   Recovered        12282 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(2)
# memory usage: 863.6+ KB
# C:\Users\Bruno Ortega\AppData\Local\Temp\ipykernel_12004\2642705637.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# Ahora ordena los valores por la última obervación, luego por país, y luego por estado

# %%
#ordenamos los valores
#Hazlo aquí
data.sort_values(["ObservationDate","Country/Region","Province/State"])
# Out:
#            SNo ObservationDate Province/State      Country/Region  \
# 38          39      2020-01-22        Unknown               China
# 12          13      2020-01-22      Hong Kong           Hong Kong
# 35          36      2020-01-22            NaN               Japan
# 39          40      2020-01-22            NaN            Kiribati
# 20          21      2020-01-22          Macau               Macau
# ...        ...             ...            ...                 ...
# 305831  305832      2021-05-29            NaN             Vietnam
# 305832  305833      2021-05-29            NaN  West Bank and Gaza
# 305833  305834      2021-05-29            NaN               Yemen
# 305834  305835      2021-05-29            NaN              Zambia
# 305835  305836      2021-05-29            NaN            Zimbabwe
#
#                Last Update  Confirmed  Deaths  Recovered
# 38     2020-01-22 17:00:00        0.0     0.0        0.0
# 12     2020-01-22 17:00:00        0.0     0.0        0.0
# ...

# %% [markdown]
# Crea una nueva columna llamada "first_date", en donde se aplique **por país** el primer día en el que se empezaron a tomar registros. Luego, crea una columna llamada "days", en donde se tenga la diferencia de días que han pasado desde que se comenzó y hasta el día del último registro. ¿Cuántos días han pasado desde la última observación y la primera observación por país?

# %%
#Hazlo aquí
first_date1 = data.sort_values(["Country/Region", "ObservationDate"])
first_date1
# Out:
#        SNo ObservationDate Province/State                  Country/Region  \
# 2737  2738      2020-02-28            NaN                      Azerbaijan
# 4770  4771      2020-03-10            NaN                 ('St. Martin',)
# 2324  2325      2020-02-24            NaN                     Afghanistan
# 2419  2420      2020-02-25            NaN                     Afghanistan
# 2522  2523      2020-02-26            NaN                     Afghanistan
# ...    ...             ...            ...                             ...
# 5252  5253      2020-03-12            NaN  occupied Palestinian territory
# 5735  5736      2020-03-14            NaN  occupied Palestinian territory
# 5995  5996      2020-03-15            NaN  occupied Palestinian territory
# 6269  6270      2020-03-16            NaN  occupied Palestinian territory
# 6547  6548      2020-03-17            NaN  occupied Palestinian territory
#
#              Last Update  Confirmed  Deaths  Recovered
# ...

# %%
day=data.groupby('Country/Region')['ObservationDate'].min()
day
# Out:
# Country/Region
#  Azerbaijan                      2020-02-28
# ('St. Martin',)                  2020-03-10
# Afghanistan                      2020-02-24
# Albania                          2020-03-09
# Algeria                          2020-02-25
#                                     ...
# West Bank and Gaza               2020-03-26
# Yemen                            2020-04-10
# Zambia                           2020-03-18
# Zimbabwe                         2020-03-20
# occupied Palestinian territory   2020-03-10
# Name: ObservationDate, Length: 229, dtype: datetime64[ns]

# %%
firstday=data.groupby('Country/Region')['ObservationDate'].min().sort_values()
firstday
# Out:
# Country/Region
# Kiribati           2020-01-22
# Japan              2020-01-22
# US                 2020-01-22
# Mainland China     2020-01-22
# China              2020-01-22
#                       ...
# Lesotho            2020-05-13
# Solomon Islands    2020-10-12
# Marshall Islands   2020-10-28
# Vanuatu            2020-11-10
# Micronesia         2021-01-21
# Name: ObservationDate, Length: 229, dtype: datetime64[ns]

# %%
country = data.groupby(["Country/Region"]).sum()
country['first_date'] = data.groupby('Country/Region')['ObservationDate'].min()
country['last_date'] = data.groupby('Country/Region')['ObservationDate'].max()
country["day"] = country['last_date'] - country['first_date']
country
# Out:
#                                      SNo   Confirmed    Deaths   Recovered  \
# Country/Region
#  Azerbaijan                         2738         1.0       0.0         0.0
# ('St. Martin',)                     4771         2.0       0.0         0.0
# Afghanistan                     62458515  17026442.0  669075.0  13464399.0
# Albania                         62414429  19768869.0  375955.0  13945256.0
# Algeria                         62455940  27684358.0  834464.0  18959299.0
# ...                                  ...         ...       ...         ...
# West Bank and Gaza              62376640  41819444.0  440378.0  37003116.0
# Yemen                           62206925    962066.0  237613.0    506523.0
# Zambia                          62439888  13493953.0  205990.0  12625626.0
# Zimbabwe                        62426441   6484581.0  237234.0   5594887.0
# occupied Palestinian territory     39525        25.0       0.0         0.0
#
# ...

# %% [markdown]
# Revisa. ¿Es esta nueva columna tiene un tipo de dato correcto?

# %%
#hazlo aquí
country.dtypes
# Out:
# SNo                     int64
# Confirmed             float64
# Deaths                float64
# Recovered             float64
# first_date     datetime64[ns]
# last_date      datetime64[ns]
# day           timedelta64[ns]
# dtype: object

# %% [markdown]
# ## última actualización de la base de datos

# %% [markdown]
# Selecciona e imprime el número de casos mundiales **totales** que se han registrado hasta la fecha. Imprime:
# - Total de casos confirmados
# - Total de muertes
# - Total de gente recuperada
# - Death rate (definela como la muertes totales / confirmados)

# %%
#Hazlo aquí
world_cases = data["Confirmed"].sum()

deads = data["Deaths"].sum()

recovery = data["Recovered"].sum()

Death_rate = deads/world_cases


print(world_cases, deads, recovery, Death_rate)
# Out:
# 26252051758.0 624013017.0 15450237912.0 0.023770066536221858

# %%
data["Deaths"].sum()
# Out:
# 624013017.0

# %% [markdown]
# Ahora realiza la misma métrica, pero agrupando por países. ¿Cuál es el país con mayor número de confirmados? Luego, ordena los registros por el número de casos confirmados

# %%
#Hazlo aquí

# %% [markdown]
# ## gráficas

# %% [markdown]
# Crea una función que reciba de parámetros dos cosas: una columna, y el título y te genera una **gráfica de barras** en donde te muestre el top 15 de países de ésa columna con los datos **a la fecha**.
#
# Por ejemplo, sería plot_new("Confirmados", "este es mi título")
# Y esto nos traería una gráfica de barras con el top 15 de países que tengan mayor número de confirmados **a la fecha**

# %%
#Hazlo aquí

# %% [markdown]
# Después revisa el siguiente caso

# %%
plt.figure(figsize=(17,20))
plt.subplot(311)
plot_new('Confirmed','Confirmed cases top 15 countries')

# %% [markdown]
# Ahora revisa para la columna de "Deaths"

# %%
# al solo cambiar los parametros obtenemos una nueva grafica
#plot_new('Deaths','Death cases top 15 countries')

# %% [markdown]
# Y activos

# %%
#plot_new('Active','Active cases top 15 countries')

# %% [markdown]
# Modifica tu función anterior de tal forma que le puedas añadir un nuevo parámetro llamado "rank". Si este es "top", te mostrará el top 15 países para la columna que hayas seleccionado. Si este es "bottom", te mostrará los 15 más bajos. Tmabién filtra mejor tu selección para únicamente mostrar a países que tengan 10 o más muertes. Y después muestra los países con el death rate más alto y más bajo

# %%
# Hazlo aquí

# %% [markdown]
# Crea un subplot de 2x2 en donde se muestre el número de casos confirmads, fallecidos, casos activos y death rate a través del tiempo de forma global a través del tiempo

# %%
# Hazlo aquí

# %% [markdown]
# Modifica el código anterior de tal forma que lo puedas hacer con el país que quieras

# %%
#Hazlo aquí

# %% [markdown]
# Imprime para mainland china, méxico, Chile y Perú

# %% [markdown]
# ## comparación entre paises

# %% [markdown]
# Crea una comparación entre países. Como si fuera la gráfica anterior, pero grafica la evolución de casos confirmados para cada país y en el eje **x no tengas la fecha**, sino el número de días que han pasado. ¿Qué podrías concluir de utilizar el número de días a utilizar la fecha?

# %%
#Hazlo aquí

# %% [markdown]
# Modifica tu código anterior para mostrar la misma gráfica, pero selecciona únicamente los países que están en el top10 de fallecidos **a la fecha**

# %%
#Hazlo aquí

# %% [markdown]
# Realiza lo mismo, pero ahora con los países que entraron primero a la pandemia.
#
# Hint: revisa cuáles son los primeros 10 países en entrar y utiliza isin() en la columna de país

# %%
#Hazlo aquí

# %% [markdown]
# Muestra el top 15 de países con la mayor death rate

# %%
#Hazlo aquí

# %% [markdown]
# Crea un mapa interactivo con el número de casos actuales confirmados utilizando scatter_geo. Para esto necesitarás pegar la columna de código de 3 números por país por ejemplo, Mexico = MEX. Canada = CAN, etc. Haz que los tamaños de los puntitos sean de acuerdo al número de casos confirmados

# %% [markdown]
# ## mapa
