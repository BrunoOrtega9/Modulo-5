# %%
import pandas as pd
import numpy as np

# %%
Sales = pd.read_csv("sales.csv")
Sales
# Out:
#        Year       Product line      Product type                      Product  \
# 0      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17818  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17819  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17820  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17821  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17822  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
# ...

# %%
len(Sales)
# Out:
# 17823

# %%
Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17823 entries, 0 to 17822
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               17823 non-null  int64
#  1   Product line       17823 non-null  object
#  2   Product type       17823 non-null  object
#  3   Product            17823 non-null  object
#  4   Order method type  17823 non-null  object
#  5   Retailer country   17823 non-null  object
#  6   Revenue            6045 non-null   float64
#  7   Planned revenue    6045 non-null   float64
#  8   Product cost       6045 non-null   float64
#  9   Quantity           5860 non-null   float64
#  10  Unit cost          6045 non-null   float64
#  11  Unit price         6045 non-null   float64
#  12  Gross profit       6045 non-null   float64
#  13  Unit sale price    6045 non-null   float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 1.9+ MB

# %%
Sales.count()
# Out:
# Year                 17823
# Product line         17823
# Product type         17823
# Product              17823
# Order method type    17823
# Retailer country     17823
# Revenue               6045
# Planned revenue       6045
# Product cost          6045
# Quantity              5860
# Unit cost             6045
# Unit price            6045
# Gross profit          6045
# Unit sale price       6045
# dtype: int64

# %%
Sales.shape
# Out:
# (17823, 14)

# %%
Sales.describe()
# Out:
#                Year       Revenue  Planned revenue  Product cost  \
# count  17823.000000  6.045000e+03     6.045000e+03  6.045000e+03
# mean    2005.164955  1.038455e+05     1.058923e+05  5.701932e+04
# std        0.956260  1.836042e+05     1.881274e+05  1.117846e+05
# min     2004.000000  0.000000e+00     0.000000e+00  3.360000e+01
# 25%     2004.000000  1.364924e+04     1.383736e+04  5.759760e+03
# 50%     2005.000000  4.154119e+04     4.189571e+04  1.906720e+04
# 75%     2006.000000  1.120026e+05     1.144758e+05  5.796000e+04
# max     2007.000000  3.644349e+06     3.477910e+06  2.061750e+06
#
#             Quantity    Unit cost   Unit price  Gross profit  Unit sale price
# count    5860.000000  6045.000000  6045.000000  6.045000e+03      6045.000000
# mean     4691.273549    58.882618    48.900855  4.336203e+04        44.795072
# std      8950.955313   348.369401    62.814500  7.185831e+04        58.399255
# ...

# %%
Sales["Prueba"] = 90

# %%
Sales
# Out:
#        Year       Product line      Product type                      Product  \
# 0      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17818  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17819  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17820  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17821  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17822  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
# ...

# %%
datos_prueba = np.arange(0, 17823)

# %%
Sales["Prueba"] = datos_prueba
Sales
# Out:
#        Year       Product line      Product type                      Product  \
# 0      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17818  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17819  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17820  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17821  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17822  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
# ...

# %%
datos_prueba = np.random.randint (1,50, size=17823)

# %%
Sales["Prueba"] = datos_prueba
Sales
# Out:
#        Year       Product line      Product type                      Product  \
# 0      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 1      2004     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 2      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 3      2005     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# 4      2006     Golf Equipment  Golf Accessories  Course Pro Golf and Tee Set
# ...     ...                ...               ...                          ...
# 17818  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17819  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17820  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17821  2006  Camping Equipment     Sleeping Bags                   Hibernator
# 17822  2006  Camping Equipment     Sleeping Bags                   Hibernator
#
# ...

# %%
Sales["Revenue"].value_counts()
# Out:
# 0.00          28
# 432.00         4
# 36576.57       3
# 2268.00        3
# 972.00         3
#               ..
# 24129.63       1
# 7818.30        1
# 34721.82       1
# 3823.47        1
# 1175927.72     1
# Name: Revenue, Length: 5881, dtype: int64

# %%
Sales.sort_values(by="Revenue", ascending=True)
# Out:
#        Year        Product line       Product type  \
# 2899   2005      Golf Equipment   Golf Accessories
# 16618  2006  Outdoor Protection  Insect Repellents
# 16821  2006  Outdoor Protection          First Aid
# 60     2006      Golf Equipment   Golf Accessories
# 56     2006      Golf Equipment   Golf Accessories
# ...     ...                 ...                ...
# 17818  2006   Camping Equipment      Sleeping Bags
# 17819  2006   Camping Equipment      Sleeping Bags
# 17820  2006   Camping Equipment      Sleeping Bags
# 17821  2006   Camping Equipment      Sleeping Bags
# 17822  2006   Camping Equipment      Sleeping Bags
#
#                            Product Order method type Retailer country  \
# 2899           Course Pro Umbrella       Sales visit          Austria
# 16618            BugShield Extreme            E-mail           Sweden
# 16821                  Aloe Relief              Mail            Japan
# ...

# %%
sl= Sales

# %%
sl.pivot_table(index="Year", values=["Quantity", "Product cost"], aggfunc="sum")
# Out:
#       Product cost   Quantity
# Year
# 2004  8.538058e+07  7318558.0
# 2005  1.029861e+08  8453776.0
# 2006  1.209524e+08  8786835.0
# 2007  3.536268e+07  2931694.0

# %%
sl.pivot_table(index="Product type", columns="Retailer country", values="Product", aggfunc="sum")
# Out:
# Retailer country                                              Australia  \
# Product type
# Climbing Accessories  Firefly Climbing LampFirefly Rechargeable Batt...
# Cooking Gear          TrailChef Deluxe Cook SetTrailChef Deluxe Cook...
# First Aid             Deluxe Family Relief KitDeluxe Family Relief K...
# Golf Accessories      Course Pro Golf and Tee SetCourse Pro Golf and...
# Insect Repellents     BugShield Lotion LiteBugShield Lotion LiteBugS...
# Sleeping Bags         Hibernator Self - Inflating MatHibernator Self...
#
# Retailer country                                                Austria  \
# Product type
# Climbing Accessories  Firefly Climbing LampFirefly Rechargeable Batt...
# Cooking Gear          TrailChef Deluxe Cook SetTrailChef Deluxe Cook...
# First Aid             Deluxe Family Relief KitDeluxe Family Relief K...
# Golf Accessories      Course Pro Golf and Tee SetCourse Pro Golf and...
# Insect Repellents     BugShield Lotion LiteBugShield Lotion LiteBugS...
# ...

# %%
sl.pivot_table(index="Product", values=["Product cost", "Gross profit", "Quantity"], aggfunc="sum")
# Out:
#                                  Gross profit  Product cost   Quantity
# Product
# Aloe Relief                         430621.58     287301.12   149636.0
# BugShield Extreme                 10501970.95    6100689.32  2520946.0
# BugShield Lotion                   3243762.97    1701361.34   730198.0
# BugShield Lotion Lite              1786866.52     672852.00   357900.0
# BugShield Natural                  4522549.50    2158928.04  1160714.0
# BugShield Spray                    2771923.32    1299876.45   710315.0
# Calamine Relief                     346881.06     310020.84   109548.0
# Compact Relief Kit                 2205323.06    1572043.30   173561.0
# Course Pro Gloves                  4621161.67    2108778.97   832639.0
# Course Pro Golf Bag               10509106.96    6654471.80    82872.0
# Course Pro Golf and Tee Set        5052264.98    1943869.20   694239.0
# Course Pro Umbrella                4655034.55    4547322.00   757887.0
# ...
